# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_5 = pd.read_csv("merge1.csv")
df_5
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    float64
#  11  hum         610 non-null    float64
#  12  windspeed   610 non-null    float64
#  13  casual      610 non-null    float64
#  14  registered  610 non-null    float64
#  15  cnt         610 non-null    float64
# dtypes: bool(1), float64(7), int64(7), object(1)
# memory usage: 72.2+ KB

# %%
missing_counts = df_5.isnull().sum()
print(missing_counts)
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
import seaborn as sns

# %%
plt.bar(df_5['weathersit'], df_5['temp'])
plt.title("Temprature By Wheathersit")
plt.xlabel("weathersit")
plt.ylabel("temp")
plt.show()

# %%
df_6 = pd.read_csv("Dataset 3.csv")
df_6
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
missing_counts = df_6.isnull().sum()
print(missing_counts)
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df_7 = pd.merge(df_5,df_6,on='dteday',how='inner')
print(df_7)
# Out:
#      instant_x      dteday  season_x  yr_x  mnth_x  hr_x  holiday_x  \
# 0          596  28-01-2011         1     0       1     0      False
# 1          596  28-01-2011         1     0       1     0      False
# 2          596  28-01-2011         1     0       1     0      False
# 3          596  28-01-2011         1     0       1     0      False
# 4          596  28-01-2011         1     0       1     0      False
# ..         ...         ...       ...   ...     ...   ...        ...
# 115        610  28-01-2011         1     0       1    15      False
# 116        610  28-01-2011         1     0       1    15      False
# 117        610  28-01-2011         1     0       1    15      False
# 118        610  28-01-2011         1     0       1    15      False
# 119        610  28-01-2011         1     0       1    15      False
#
#      weekday_x  weathersit_x  temp_x  ...  holiday_y  weekday_y  weathersit_y  \
# ...

# %%
df_7.to_csv('merge2.csv', index=False)

# %%
df_7.to_excel('merge2.xlsx', index=False)

# %%
sns.boxplot(x=df_7['season_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['season_x'].skew()
# Out:
# 0.0

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['season_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\2448990607.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['season_x'])
# C:\Users\harmesh.pandya\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instant_x     120 non-null    int64
#  1   dteday        120 non-null    object
#  2   season_x      120 non-null    int64
#  3   yr_x          120 non-null    int64
#  4   mnth_x        120 non-null    int64
#  5   hr_x          120 non-null    int64
#  6   holiday_x     120 non-null    bool
#  7   weekday_x     120 non-null    int64
#  8   weathersit_x  120 non-null    int64
#  9   temp_x        120 non-null    float64
#  10  Unnamed: 0    120 non-null    float64
#  11  hum_x         120 non-null    float64
#  12  windspeed_x   120 non-null    float64
#  13  casual_x      120 non-null    float64
#  14  registered_x  120 non-null    float64
#  15  cnt_x         120 non-null    float64
#  16  instant_y     120 non-null    int64
#  17  season_y      120 non-null    int64
# ...

# %%
sns.boxplot(x=df_7['yr_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['yr_x'].skew()
# Out:
# 0.0

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['yr_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\1758622765.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['yr_x'])
# C:\Users\harmesh.pandya\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
sns.boxplot(x=df_7['mnth_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['mnth_x'].skew()
# Out:
# 0.0

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['mnth_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\102017622.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['mnth_x'])
# C:\Users\harmesh.pandya\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
sns.boxplot(x=df_7['hr_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['hr_x'].skew()
# Out:
# -0.1235224875291518

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['hr_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\1982328567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['hr_x'])

# %%
sns.boxplot(x=df_7['weekday_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['weekday_x'].skew()
# Out:
# 0.0

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['weekday_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\1451710878.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['weekday_x'])
# C:\Users\harmesh.pandya\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
sns.boxplot(x=df_7['weathersit_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['weathersit_x'].skew()
# Out:
# 0.41343426839493147

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['weathersit_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\2037644635.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['weathersit_x'])

# %%
sns.boxplot(x=df_7['temp_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['temp_x'].skew()
# Out:
# 0.15283754446673747

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['temp_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\2226960354.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['temp_x'])

# %%
sns.boxplot(x=df_7['Unnamed: 0'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['Unnamed: 0'].skew()
# Out:
# 0.0

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['Unnamed: 0'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\1810069960.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['Unnamed: 0'])

# %%
sns.boxplot(x=df_7['hum_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['hum_x'].skew()
# Out:
# 0.12597133349451567

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.distplot(df_7['hum_x'])
plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\1339967732.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['hum_x'])

# %%
sns.boxplot(x=df_7['windspeed_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_7['windspeed_x'].skew()
# Out:
# -1.179283280187078

# %%
perc25=df_7['windspeed_x'].quantile(0.25)
perc75=df_7['windspeed_x'].quantile(0.75)

perc25
# Out:
# 0.0896

# %%
perc75
# Out:
# 0.1343

# %%
iqr=perc75-perc25
iqr
# Out:
# 0.044700000000000004

# %%
upper_limit=perc75+1.5*iqr
lower_limit=perc25-1.5*iqr

# %%
print("Upper Limit",upper_limit)
print("Lower Limit",lower_limit)
# Out:
# Upper Limit 0.20135
# Lower Limit 0.02255

# %%
df_8 = df_7.copy()

# %%
df_8['windspeed_x']=np.where(
    df_8['windspeed_x']>upper_limit,
    upper_limit,
    np.where(
        df_8['windspeed_x']<lower_limit,
        lower_limit,
        df_8['windspeed_x']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_7['windspeed_x'])

plt.subplot(2,2,2)
sns.boxplot(df_7['windspeed_x'])

plt.subplot(2,2,3)
sns.distplot(df_8['windspeed_x'])

plt.subplot(2,2,4)
sns.boxplot(df_8['windspeed_x'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\2990584308.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_7['windspeed_x'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\2990584308.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_8['casual_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
perc25a=df_8['casual_x'].quantile(0.25)
perc75a=df_8['casual_x'].quantile(0.75)

perc25a
# Out:
# 0.0

# %%
perc75a
# Out:
# 2.0

# %%
iqr1=perc75a-perc25a
iqr1
# Out:
# 2.0

# %%
upper_limit1=perc75a+1.5*iqr1
lower_limit1=perc25a-1.5*iqr1

# %%
print("Upper Limit",upper_limit1)
print("Lower Limit",lower_limit1)
# Out:
# Upper Limit 5.0
# Lower Limit -3.0

# %%
df_9 = df_8.copy()

# %%
df_9['casual_x']=np.where(
    df_9['casual_x']>upper_limit1,
    upper_limit1,
    np.where(
        df_9['casual_x']<lower_limit1,
        lower_limit1,
        df_9['casual_x']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_8['casual_x'])

plt.subplot(2,2,2)
sns.boxplot(df_8['casual_x'])

plt.subplot(2,2,3)
sns.distplot(df_9['casual_x'])

plt.subplot(2,2,4)
sns.boxplot(df_9['casual_x'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\3779717902.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_8['casual_x'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\3779717902.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_9['registered_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
perc25b=df_9['registered_x'].quantile(0.25)
perc75b=df_9['registered_x'].quantile(0.75)

perc25b
# Out:
# 4.0

# %%
perc75b
# Out:
# 49.0

# %%
iqr2=perc75b-perc25b
iqr2
# Out:
# 45.0

# %%
upper_limit2=perc75b+1.5*iqr2
lower_limit2=perc25b-1.5*iqr2

# %%
print("Upper Limit",upper_limit2)
print("Lower Limit",lower_limit2)
# Out:
# Upper Limit 116.5
# Lower Limit -63.5

# %%
df_10 = df_9.copy()

# %%
df_10['registered_x']=np.where(
    df_10['registered_x']>upper_limit2,
    upper_limit2,
    np.where(
        df_10['registered_x']<lower_limit2,
        lower_limit2,
        df_10['registered_x']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_9['registered_x'])

plt.subplot(2,2,2)
sns.boxplot(df_9['registered_x'])

plt.subplot(2,2,3)
sns.distplot(df_10['registered_x'])

plt.subplot(2,2,4)
sns.boxplot(df_10['registered_x'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\3230705937.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_9['registered_x'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\3230705937.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_10['cnt_x'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
perc25c=df_10['cnt_x'].quantile(0.25)
perc75c=df_10['cnt_x'].quantile(0.75)

perc25c
# Out:
# 4.0

# %%
perc75c
# Out:
# 49.0

# %%
iqr3=perc75c-perc25c
iqr3
# Out:
# 45.0

# %%
upper_limit3=perc75c+1.5*iqr3
lower_limit3=perc25c-1.5*iqr3

# %%
print("Upper Limit",upper_limit3)
print("Lower Limit",lower_limit3)
# Out:
# Upper Limit 116.5
# Lower Limit -63.5

# %%
df_11 = df_10.copy()

# %%
df_11['cnt_x']=np.where(
    df_11['cnt_x']>upper_limit3,
    upper_limit3,
    np.where(
        df_11['cnt_x']<lower_limit3,
        lower_limit3,
        df_11['cnt_x']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_10['cnt_x'])

plt.subplot(2,2,2)
sns.boxplot(df_10['cnt_x'])

plt.subplot(2,2,3)
sns.distplot(df_11['cnt_x'])

plt.subplot(2,2,4)
sns.boxplot(df_11['cnt_x'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\4113054138.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_10['cnt_x'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\4113054138.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_11['instant_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_11['season_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_11['yr_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_11['mnth_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_11['hr_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_11['weekday_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_11['weathersit_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_11['temp_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
perc25d=df_11['temp_y'].quantile(0.25)
perc75d=df_11['temp_y'].quantile(0.75)

perc25d
# Out:
# 0.235

# %%
perc75d
# Out:
# 0.24

# %%
iqr4=perc75d-perc25d
iqr4
# Out:
# 0.0050000000000000044

# %%
upper_limit4=perc75d+1.5*iqr4
lower_limit4=perc25d-1.5*iqr4

# %%
print("Upper Limit",upper_limit4)
print("Lower Limit",lower_limit4)
# Out:
# Upper Limit 0.2475
# Lower Limit 0.22749999999999998

# %%
df_12 = df_11.copy()

# %%
df_12['temp_y']=np.where(
    df_12['temp_y']>upper_limit4,
    upper_limit4,
    np.where(
        df_12['temp_y']<lower_limit4,
        lower_limit4,
        df_12['temp_y']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_11['temp_y'])

plt.subplot(2,2,2)
sns.boxplot(df_11['temp_y'])

plt.subplot(2,2,3)
sns.distplot(df_12['temp_y'])

plt.subplot(2,2,4)
sns.boxplot(df_12['temp_y'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\96131719.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_11['temp_y'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\96131719.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_12['atemp'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
perc25e=df_12['atemp'].quantile(0.25)
perc75e=df_12['atemp'].quantile(0.75)

perc25e
# Out:
# 0.2273

# %%
perc75e
# Out:
# 0.2424

# %%
iqr5=perc75e-perc25e
iqr5
# Out:
# 0.015100000000000002

# %%
upper_limit5=perc75e+1.5*iqr5
lower_limit5=perc25e-1.5*iqr5

# %%
print("Upper Limit",upper_limit5)
print("Lower Limit",lower_limit5)
# Out:
# Upper Limit 0.26505
# Lower Limit 0.20465

# %%
df_13 = df_12.copy()

# %%
df_13['atemp']=np.where(
    df_13['atemp']>upper_limit5,
    upper_limit5,
    np.where(
        df_13['atemp']<lower_limit5,
        lower_limit5,
        df_13['atemp']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_12['atemp'])

plt.subplot(2,2,2)
sns.boxplot(df_12['atemp'])

plt.subplot(2,2,3)
sns.distplot(df_13['atemp'])

plt.subplot(2,2,4)
sns.boxplot(df_13['atemp'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\842609033.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_12['atemp'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\842609033.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_13['hum_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_13['windspeed_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
perc25f=df_13['windspeed_y'].quantile(0.25)
perc75f=df_13['windspeed_y'].quantile(0.75)

perc25f
# Out:
# 0.1343

# %%
perc75f
# Out:
# 0.20147500000000002

# %%
iqr6=perc75f-perc25f
iqr6
# Out:
# 0.06717500000000001

# %%
upper_limit6=perc75f+1.5*iqr6
lower_limit6=perc25f-1.5*iqr6

# %%
print("Upper Limit",upper_limit6)
print("Lower Limit",lower_limit6)
# Out:
# Upper Limit 0.30223750000000005
# Lower Limit 0.033537499999999984

# %%
df_14 = df_13.copy()

# %%
df_14['windspeed_y']=np.where(
    df_14['windspeed_y']>upper_limit6,
    upper_limit6,
    np.where(
        df_14['windspeed_y']<lower_limit6,
        lower_limit6,
        df_14['windspeed_y']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_13['windspeed_y'])

plt.subplot(2,2,2)
sns.boxplot(df_13['windspeed_y'])

plt.subplot(2,2,3)
sns.distplot(df_14['windspeed_y'])

plt.subplot(2,2,4)
sns.boxplot(df_14['windspeed_y'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\3070971100.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_13['windspeed_y'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\3070971100.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_14['casual_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
perc25g=df_14['casual_y'].quantile(0.25)
perc75g=df_14['casual_y'].quantile(0.75)

perc25g
# Out:
# 1.0

# %%
perc75g
# Out:
# 2.75

# %%
iqr7=perc75g-perc25g
iqr7
# Out:
# 1.75

# %%
upper_limit7=perc75g+1.5*iqr7
lower_limit7=perc25g-1.5*iqr7

# %%
print("Upper Limit",upper_limit7)
print("Lower Limit",lower_limit7)
# Out:
# Upper Limit 5.375
# Lower Limit -1.625

# %%
df_15 = df_14.copy()

# %%
df_15['casual_y']=np.where(
    df_15['casual_y']>upper_limit7,
    upper_limit7,
    np.where(
        df_15['casual_y']<lower_limit7,
        lower_limit7,
        df_15['casual_y']
    )
)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1)
sns.distplot(df_14['casual_y'])

plt.subplot(2,2,2)
sns.boxplot(df_14['casual_y'])

plt.subplot(2,2,3)
sns.distplot(df_15['casual_y'])

plt.subplot(2,2,4)
sns.boxplot(df_15['casual_y'])

plt.show()
# Out:
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\2877846498.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_14['casual_y'])
# C:\Users\harmesh.pandya\AppData\Local\Temp\ipykernel_19468\2877846498.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df_15['registered_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
sns.boxplot(x=df_15['cnt_y'])
plt.title("Boxplot to Detect Outliers")
plt.show()

# %%
df_15['weathersit_x'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("weathersit_x Distribution")
plt.ylabel("")  
plt.show()

# %%
sns.scatterplot(x='windspeed_x', y='hum_x', data=df_15)
plt.title("Windspeed vs Humidity")
plt.show()

# %%
sns.barplot(x='windspeed_x', y='hum_x', data=df_15)
plt.title("Windspeed vs Humidity")
plt.show()

# %%
df_15.to_csv('merge2_Outlier_removed.csv', index=False)

# %%
df_15.to_excel('merge2_Outlier_removed.xlsx', index=False)
